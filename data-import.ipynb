# %% [markdown]
# # Data Importing
#
# This file includes the API calls to Alpha Vantage. We collect minute by minute data for 2022-2024. We had to make calls for one month at a time and aggregate into one csv file with all three years. Succesfully downloads data for over 1,400 stocks.
#
# We provided in the repository the 20 stocks' csv files (chosen by highest correlation as explained in report) that are in our final portfolio. **Running this file is not recomended**

# %%
import requests
import pandas as pd
import numpy as np 
import csv
import os
import time

# %%
def fetch(tickers, api_key, months, folder_name):

    # Create the folder if it doesn't exist
    if not os.path.exists(folder_name):
        os.makedirs(folder_name)
    
    # Fetch and save the data for each ticker
    call_count = 0
    for ticker in tickers:

        file_path = os.path.join(folder_name, f"{ticker}_2022-2024_1min.csv") # make name have timeframe
        

        if os.path.isfile(file_path):
            print(f"{ticker}_1min.csv already exists, check that it is correct.")
            continue
        else:
                url = "https://www.alphavantage.co/query"
                params = {
                    "function": "TIME_SERIES_INTRADAY",
                    "symbol": ticker,
                    "interval": "1min",
                    "month": months[0],
                    "outputsize": "full",
                    "apikey": api_key,
                    "extended_hours": "false"
                }
                # Fetch the data
                response = requests.get(url, params=params)
                call_count += 1
                try:
                    data = response.json()['Time Series (1min)']
                    main_df = pd.DataFrame.from_dict(data, orient='index')
                    main_df.dropna(inplace=True)
                    main_df = main_df.iloc[::-1]
                except Exception as e:
                    print(f"Could not get data for {ticker}")
                    print(response)
                    continue
                main_df = None
                for month in months[1:]:
                    url = "https://www.alphavantage.co/query"
                    params = {
                        "function": "TIME_SERIES_INTRADAY",
                        "symbol": ticker,
                        "interval": "1min",
                        "month": month,
                        "outputsize": "full",
                        "apikey": api_key,
                        "extended_hours": "false"
                    }
                    # Fetch the data
                    response = requests.get(url, params=params)
                    call_count += 1
                    try:
                        data = response.json()['Time Series (1min)']
                        df = pd.DataFrame.from_dict(data, orient='index')
                        df.dropna(inplace=True)
                        df = df.iloc[::-1]
                        main_df = pd.concat([main_df, df], join='inner')
                    except Exception as e:
                        print(f"Could not get data for {ticker}")
                        print(response)
                        continue
                if main_df is not None:
                    main_df.columns = ["open", "high", "low", "close", "volume"]
                    main_df.index.name = "timestamp"
                    main_df.to_csv(file_path, index=True)

                print(f"Data for {ticker} saved in {file_path}")
    return call_count

# %%
# batch fetch used because API has 75 calls per minute limit

def batch_fetch(all_tickers, months, folder_name, api_key, batch_size=6, delay=60):
    api_call_count = 0
    for i in range(0, len(all_tickers), batch_size):
        batch = all_tickers[i:i+batch_size]
        api_call_count += fetch(batch, api_key, months, folder_name)
        if api_call_count >= 74:
            print("Waiting 1 minute before next batch...")
            time.sleep(delay)
            api_call_count = 0  # reset after delay

# %%
tickers = pd.read_csv("full_tickers/2-1000_tickers.csv", header=None, names=['ticker'])

api_key = "R9ET6ZUJMPWT7N42"

start_date = pd.to_datetime("2025-02")


start_date = pd.to_datetime("2022-01")
end_date = pd.to_datetime("2024-12")

# Generate list of months between start and end dates
months = pd.date_range(start=start_date, end=end_date, freq='MS').strftime("%Y-%m").tolist()
folder_name = '2022-2024 1min data'

# %%
batch_fetch(tickers["ticker"], months, folder_name, api_key, 6, 60)
# Out:
# LNT_1min.csv already exists, check that it is correct.
# WRB_1min.csv already exists, check that it is correct.
# NTR_1min.csv already exists, check that it is correct.
# VRSK_1min.csv already exists, check that it is correct.
# FUTU_1min.csv already exists, check that it is correct.
# PRU_1min.csv already exists, check that it is correct.
# WPM_1min.csv already exists, check that it is correct.
# KMX_1min.csv already exists, check that it is correct.
# STRL_1min.csv already exists, check that it is correct.
# SNY_1min.csv already exists, check that it is correct.
# FLEX_1min.csv already exists, check that it is correct.
# ASTS_1min.csv already exists, check that it is correct.
# APLD_1min.csv already exists, check that it is correct.
# BIIB_1min.csv already exists, check that it is correct.
# W_1min.csv already exists, check that it is correct.
# SAIA_1min.csv already exists, check that it is correct.
# APTV_1min.csv already exists, check that it is correct.
# HES_1min.csv already exists, check that it is correct.
# ATO_1min.csv already exists, check that it is correct.
# AVTR_1min.csv already exists, check that it is correct.
# IAG_1min.csv already exists, check that it is correct.
# IEX_1min.csv already exists, check that it is correct.
# DEO_1min.csv already exists, check that it is correct.
# Could not get data for SGI
# <Response [200]>
# ALNY_1min.csv already exists, check that it is correct.
# MAA_1min.csv already exists, check that it is correct.
# AWK_1min.csv already exists, check that it is correct.
# LYFT_1min.csv already exists, check that it is correct.
# ALGN_1min.csv already exists, check that it is correct.
# DVA_1min.csv already exists, check that it is correct.
# AR_1min.csv already exists, check that it is correct.
# Could not get data for RBRK
# <Response [200]>
# SJM_1min.csv already exists, check that it is correct.
# CACI_1min.csv already exists, check that it is correct.
# WSO_1min.csv already exists, check that it is correct.
# WAT_1min.csv already exists, check that it is correct.
# BBWI_1min.csv already exists, check that it is correct.
# CTRA_1min.csv already exists, check that it is correct.
# STM_1min.csv already exists, check that it is correct.
# EXPD_1min.csv already exists, check that it is correct.
# JBL_1min.csv already exists, check that it is correct.
# FR_1min.csv already exists, check that it is correct.
# IR_1min.csv already exists, check that it is correct.
# EME_1min.csv already exists, check that it is correct.
# RHI_1min.csv already exists, check that it is correct.
# MNDY_1min.csv already exists, check that it is correct.
# RIOT_1min.csv already exists, check that it is correct.
# TPL_1min.csv already exists, check that it is correct.
# EVRG_1min.csv already exists, check that it is correct.
# HRB_1min.csv already exists, check that it is correct.
# TOL_1min.csv already exists, check that it is correct.
# HEI_1min.csv already exists, check that it is correct.
# NTES_1min.csv already exists, check that it is correct.
# GTLB_1min.csv already exists, check that it is correct.
# CLX_1min.csv already exists, check that it is correct.
# NTAP_1min.csv already exists, check that it is correct.
# Could not get data for TLN
# <Response [200]>
# TECH_1min.csv already exists, check that it is correct.
# Data for WCC saved in 2022-2024 1min data\WCC_2022-2024_1min.csv
# CCEP_1min.csv already exists, check that it is correct.
# EXAS_1min.csv already exists, check that it is correct.
# SWKS_1min.csv already exists, check that it is correct.
# ACGL_1min.csv already exists, check that it is correct.
# ONON_1min.csv already exists, check that it is correct.
# FND_1min.csv already exists, check that it is correct.
# NTRS_1min.csv already exists, check that it is correct.
# CP_1min.csv already exists, check that it is correct.
# BRKR_1min.csv already exists, check that it is correct.
# ETSY_1min.csv already exists, check that it is correct.
# Data for BMI saved in 2022-2024 1min data\BMI_2022-2024_1min.csv
# EQH_1min.csv already exists, check that it is correct.
# RRC_1min.csv already exists, check that it is correct.
# Waiting 1 minute before next batch...
# TWLO_1min.csv already exists, check that it is correct.
# TYL_1min.csv already exists, check that it is correct.
# RY_1min.csv already exists, check that it is correct.
# LPLA_1min.csv already exists, check that it is correct.
# ARE_1min.csv already exists, check that it is correct.
# Could not get data for GPCR
# <Response [200]>
# BR_1min.csv already exists, check that it is correct.
# CROX_1min.csv already exists, check that it is correct.
# OLLI_1min.csv already exists, check that it is correct.
# MGM_1min.csv already exists, check that it is correct.
# PATH_1min.csv already exists, check that it is correct.
# FHN_1min.csv already exists, check that it is correct.
# EMN_1min.csv already exists, check that it is correct.
# BG_1min.csv already exists, check that it is correct.
# Could not get data for EG
# <Response [200]>
# Could not get data for RVTY
# <Response [200]>
# MLM_1min.csv already exists, check that it is correct.
# STLD_1min.csv already exists, check that it is correct.
# NLY_1min.csv already exists, check that it is correct.
# ADT_1min.csv already exists, check that it is correct.
# Data for DNB saved in 2022-2024 1min data\DNB_2022-2024_1min.csv
# CAG_1min.csv already exists, check that it is correct.
# Data for SG saved in 2022-2024 1min data\SG_2022-2024_1min.csv
# VKTX_1min.csv already exists, check that it is correct.
# Waiting 1 minute before next batch...
# TEVA_1min.csv already exists, check that it is correct.
# ITUB_1min.csv already exists, check that it is correct.
# Could not get data for ONC
# <Response [200]>
# UPST_1min.csv already exists, check that it is correct.
# DKS_1min.csv already exists, check that it is correct.
# APA_1min.csv already exists, check that it is correct.
# CBOE_1min.csv already exists, check that it is correct.
# AKAM_1min.csv already exists, check that it is correct.
# Data for MAN saved in 2022-2024 1min data\MAN_2022-2024_1min.csv
# PNR_1min.csv already exists, check that it is correct.
# MTZ_1min.csv already exists, check that it is correct.
# THC_1min.csv already exists, check that it is correct.
# ELF_1min.csv already exists, check that it is correct.
# PFG_1min.csv already exists, check that it is correct.
# CIEN_1min.csv already exists, check that it is correct.
# FIX_1min.csv already exists, check that it is correct.
# CVE_1min.csv already exists, check that it is correct.
# WYNN_1min.csv already exists, check that it is correct.
# GFI_1min.csv already exists, check that it is correct.
# AG_1min.csv already exists, check that it is correct.
# PYCR_1min.csv already exists, check that it is correct.
# PLUG_1min.csv already exists, check that it is correct.
# ANF_1min.csv already exists, check that it is correct.
# BHP_1min.csv already exists, check that it is correct.
# OWL_1min.csv already exists, check that it is correct.
# Data for CGNX saved in 2022-2024 1min data\CGNX_2022-2024_1min.csv
# EIX_1min.csv already exists, check that it is correct.
# BN_1min.csv already exists, check that it is correct.
# CNI_1min.csv already exists, check that it is correct.
# Data for ALHC saved in 2022-2024 1min data\ALHC_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# MOS_1min.csv already exists, check that it is correct.
# Could not get data for ALAB
# <Response [200]>
# ROL_1min.csv already exists, check that it is correct.
# PTEN_1min.csv already exists, check that it is correct.
# EPD_1min.csv already exists, check that it is correct.
# OZK_1min.csv already exists, check that it is correct.
# Could not get data for SOUN
# <Response [200]>
# Could not get data for RHHBY
# <Response [200]>
# Data for HLNE saved in 2022-2024 1min data\HLNE_2022-2024_1min.csv
# EQNR_1min.csv already exists, check that it is correct.
# Data for SNV saved in 2022-2024 1min data\SNV_2022-2024_1min.csv
# Z_1min.csv already exists, check that it is correct.
# Waiting 1 minute before next batch...
# VFC_1min.csv already exists, check that it is correct.
# Data for SXTC saved in 2022-2024 1min data\SXTC_2022-2024_1min.csv
# SNX_1min.csv already exists, check that it is correct.
# WING_1min.csv already exists, check that it is correct.
# NGG_1min.csv already exists, check that it is correct.
# EWBC_1min.csv already exists, check that it is correct.
# Could not get data for CPAY
# <Response [200]>
# SONY_1min.csv already exists, check that it is correct.
# CLF_1min.csv already exists, check that it is correct.
# INSM_1min.csv already exists, check that it is correct.
# FDS_1min.csv already exists, check that it is correct.
# ITT_1min.csv already exists, check that it is correct.
# PSTG_1min.csv already exists, check that it is correct.
# CG_1min.csv already exists, check that it is correct.
# AIT_1min.csv already exists, check that it is correct.
# HMY_1min.csv already exists, check that it is correct.
# XPEV_1min.csv already exists, check that it is correct.
# H_1min.csv already exists, check that it is correct.
# MAS_1min.csv already exists, check that it is correct.
# LSCC_1min.csv already exists, check that it is correct.
# AVY_1min.csv already exists, check that it is correct.
# MTDR_1min.csv already exists, check that it is correct.
# IPG_1min.csv already exists, check that it is correct.
# AES_1min.csv already exists, check that it is correct.
# WIX_1min.csv already exists, check that it is correct.
# DT_1min.csv already exists, check that it is correct.
# RACE_1min.csv already exists, check that it is correct.
# Could not get data for TKO
# <Response [200]>
# MANH_1min.csv already exists, check that it is correct.
# RGLD_1min.csv already exists, check that it is correct.
# OVV_1min.csv already exists, check that it is correct.
# FFIV_1min.csv already exists, check that it is correct.
# BE_1min.csv already exists, check that it is correct.
# MKSI_1min.csv already exists, check that it is correct.
# IOT_1min.csv already exists, check that it is correct.
# SU_1min.csv already exists, check that it is correct.
# Data for UUUU saved in 2022-2024 1min data\UUUU_2022-2024_1min.csv
# CE_1min.csv already exists, check that it is correct.
# Data for ASND saved in 2022-2024 1min data\ASND_2022-2024_1min.csv
# Data for ASB saved in 2022-2024 1min data\ASB_2022-2024_1min.csv
# EHC_1min.csv already exists, check that it is correct.
# TDY_1min.csv already exists, check that it is correct.
# Waiting 1 minute before next batch...
# DOCS_1min.csv already exists, check that it is correct.
# MTCH_1min.csv already exists, check that it is correct.
# RNR_1min.csv already exists, check that it is correct.
# Data for TXT saved in 2022-2024 1min data\TXT_2022-2024_1min.csv
# SRPT_1min.csv already exists, check that it is correct.
# Could not get data for BULL
# <Response [200]>
# ZM_1min.csv already exists, check that it is correct.
# FWONK_1min.csv already exists, check that it is correct.
# FCNCA_1min.csv already exists, check that it is correct.
# TW_1min.csv already exists, check that it is correct.
# ALK_1min.csv already exists, check that it is correct.
# UHS_1min.csv already exists, check that it is correct.
# JAZZ_1min.csv already exists, check that it is correct.
# RIG_1min.csv already exists, check that it is correct.
# KNX_1min.csv already exists, check that it is correct.
# Data for MSGM saved in 2022-2024 1min data\MSGM_2022-2024_1min.csv
# Could not get data for OKLO
# <Response [200]>
# EXR_1min.csv already exists, check that it is correct.
# Waiting 1 minute before next batch...
# ALLE_1min.csv already exists, check that it is correct.
# Data for MGNI saved in 2022-2024 1min data\MGNI_2022-2024_1min.csv
# FTV_1min.csv already exists, check that it is correct.
# STE_1min.csv already exists, check that it is correct.
# Data for AGX saved in 2022-2024 1min data\AGX_2022-2024_1min.csv
# Could not get data for RGTI
# <Response [200]>
# Could not get data for SN
# <Response [200]>
# ESS_1min.csv already exists, check that it is correct.
# XPO_1min.csv already exists, check that it is correct.
# ITGR_1min.csv already exists, check that it is correct.
# PAAS_1min.csv already exists, check that it is correct.
# Data for VIST saved in 2022-2024 1min data\VIST_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# COHR_1min.csv already exists, check that it is correct.
# CNM_1min.csv already exists, check that it is correct.
# DOCU_1min.csv already exists, check that it is correct.
# CORT_1min.csv already exists, check that it is correct.
# RGEN_1min.csv already exists, check that it is correct.
# Data for MWA saved in 2022-2024 1min data\MWA_2022-2024_1min.csv
# PLNT_1min.csv already exists, check that it is correct.
# CSL_1min.csv already exists, check that it is correct.
# Data for ONB saved in 2022-2024 1min data\ONB_2022-2024_1min.csv
# SHAK_1min.csv already exists, check that it is correct.
# HL_1min.csv already exists, check that it is correct.
# UAA_1min.csv already exists, check that it is correct.
# KEYS_1min.csv already exists, check that it is correct.
# CPB_1min.csv already exists, check that it is correct.
# CZR_1min.csv already exists, check that it is correct.
# PKG_1min.csv already exists, check that it is correct.
# VOD_1min.csv already exists, check that it is correct.
# TD_1min.csv already exists, check that it is correct.
# Data for TREX saved in 2022-2024 1min data\TREX_2022-2024_1min.csv
# CHRW_1min.csv already exists, check that it is correct.
# Data for ATI saved in 2022-2024 1min data\ATI_2022-2024_1min.csv
# Data for GLBE saved in 2022-2024 1min data\GLBE_2022-2024_1min.csv
# PTC_1min.csv already exists, check that it is correct.
# ELS_1min.csv already exists, check that it is correct.
# Waiting 1 minute before next batch...
# LYG_1min.csv already exists, check that it is correct.
# CCJ_1min.csv already exists, check that it is correct.
# KBH_1min.csv already exists, check that it is correct.
# Could not get data for PRMB
# <Response [200]>
# UMC_1min.csv already exists, check that it is correct.
# AGI_1min.csv already exists, check that it is correct.
# GWRE_1min.csv already exists, check that it is correct.
# Could not get data for NSRGY
# <Response [200]>
# ALC_1min.csv already exists, check that it is correct.
# NVT_1min.csv already exists, check that it is correct.
# SCCO_1min.csv already exists, check that it is correct.
# Could not get data for QBTS
# <Response [200]>
# TAP_1min.csv already exists, check that it is correct.
# Data for INSP saved in 2022-2024 1min data\INSP_2022-2024_1min.csv
# Data for R saved in 2022-2024 1min data\R_2022-2024_1min.csv
# UDR_1min.csv already exists, check that it is correct.
# PEN_1min.csv already exists, check that it is correct.
# ADC_1min.csv already exists, check that it is correct.
# Waiting 1 minute before next batch...
# EVR_1min.csv already exists, check that it is correct.
# Data for SBSW saved in 2022-2024 1min data\SBSW_2022-2024_1min.csv
# BXP_1min.csv already exists, check that it is correct.
# XP_1min.csv already exists, check that it is correct.
# HSIC_1min.csv already exists, check that it is correct.
# AUR_1min.csv already exists, check that it is correct.
# USFD_1min.csv already exists, check that it is correct.
# Could not get data for PBR.A
# <Response [200]>
# Data for AGL saved in 2022-2024 1min data\AGL_2022-2024_1min.csv
# Could not get data for SMX
# <Response [200]>
# Data for RBC saved in 2022-2024 1min data\RBC_2022-2024_1min.csv
# TECK_1min.csv already exists, check that it is correct.
# Waiting 1 minute before next batch...
# HALO_1min.csv already exists, check that it is correct.
# HSBC_1min.csv already exists, check that it is correct.
# NTRA_1min.csv already exists, check that it is correct.
# Data for VSEC saved in 2022-2024 1min data\VSEC_2022-2024_1min.csv
# MPLX_1min.csv already exists, check that it is correct.
# ZBRA_1min.csv already exists, check that it is correct.
# CRDO_1min.csv already exists, check that it is correct.
# U_1min.csv already exists, check that it is correct.
# Data for RNST saved in 2022-2024 1min data\RNST_2022-2024_1min.csv
# CPNG_1min.csv already exists, check that it is correct.
# SF_1min.csv already exists, check that it is correct.
# AYI_1min.csv already exists, check that it is correct.
# PAYC_1min.csv already exists, check that it is correct.
# HRL_1min.csv already exists, check that it is correct.
# Data for VNOM saved in 2022-2024 1min data\VNOM_2022-2024_1min.csv
# AOS_1min.csv already exists, check that it is correct.
# UBS_1min.csv already exists, check that it is correct.
# Data for HXL saved in 2022-2024 1min data\HXL_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# WHR_1min.csv already exists, check that it is correct.
# SLNO_1min.csv already exists, check that it is correct.
# ARCC_1min.csv already exists, check that it is correct.
# FTI_1min.csv already exists, check that it is correct.
# UTHR_1min.csv already exists, check that it is correct.
# INVH_1min.csv already exists, check that it is correct.
# DTM_1min.csv already exists, check that it is correct.
# BROS_1min.csv already exists, check that it is correct.
# UNM_1min.csv already exists, check that it is correct.
# TMDX_1min.csv already exists, check that it is correct.
# ASX_1min.csv already exists, check that it is correct.
# Data for UBSI saved in 2022-2024 1min data\UBSI_2022-2024_1min.csv
# WBA_1min.csv already exists, check that it is correct.
# Could not get data for NBIS
# <Response [200]>
# NGD_1min.csv already exists, check that it is correct.
# HTHT_1min.csv already exists, check that it is correct.
# SMMT_1min.csv already exists, check that it is correct.
# Data for JLL saved in 2022-2024 1min data\JLL_2022-2024_1min.csv
# Data for AREC saved in 2022-2024 1min data\AREC_2022-2024_1min.csv
# Data for BWXT saved in 2022-2024 1min data\BWXT_2022-2024_1min.csv
# Data for AQN saved in 2022-2024 1min data\AQN_2022-2024_1min.csv
# URBN_1min.csv already exists, check that it is correct.
# KIM_1min.csv already exists, check that it is correct.
# Could not get data for DAY
# <Response [200]>
# Waiting 1 minute before next batch...
# Data for CWAN saved in 2022-2024 1min data\CWAN_2022-2024_1min.csv
# NOK_1min.csv already exists, check that it is correct.
# IQ_1min.csv already exists, check that it is correct.
# AEO_1min.csv already exists, check that it is correct.
# Data for BSY saved in 2022-2024 1min data\BSY_2022-2024_1min.csv
# GH_1min.csv already exists, check that it is correct.
# CCK_1min.csv already exists, check that it is correct.
# RPRX_1min.csv already exists, check that it is correct.
# Data for RRX saved in 2022-2024 1min data\RRX_2022-2024_1min.csv
# OHI_1min.csv already exists, check that it is correct.
# CWST_1min.csv already exists, check that it is correct.
# GGAL_1min.csv already exists, check that it is correct.
# Waiting 1 minute before next batch...
# PSN_1min.csv already exists, check that it is correct.
# AIZ_1min.csv already exists, check that it is correct.
# MTN_1min.csv already exists, check that it is correct.
# EXEL_1min.csv already exists, check that it is correct.
# MIDD_1min.csv already exists, check that it is correct.
# NIO_1min.csv already exists, check that it is correct.
# Data for RTO saved in 2022-2024 1min data\RTO_2022-2024_1min.csv
# Data for RBA saved in 2022-2024 1min data\RBA_2022-2024_1min.csv
# VTRS_1min.csv already exists, check that it is correct.
# TRU_1min.csv already exists, check that it is correct.
# PTON_1min.csv already exists, check that it is correct.
# DOC_1min.csv already exists, check that it is correct.
# Could not get data for BYDDY
# <Response [200]>
# SWI_1min.csv already exists, check that it is correct.
# RKT_1min.csv already exists, check that it is correct.
# QSR_1min.csv already exists, check that it is correct.
# GTLS_1min.csv already exists, check that it is correct.
# Data for HQY saved in 2022-2024 1min data\HQY_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# AGCO_1min.csv already exists, check that it is correct.
# ZION_1min.csv already exists, check that it is correct.
# ALGM_1min.csv already exists, check that it is correct.
# CDE_1min.csv already exists, check that it is correct.
# SSNC_1min.csv already exists, check that it is correct.
# MKTX_1min.csv already exists, check that it is correct.
# Could not get data for CRBG
# <Response [200]>
# ALV_1min.csv already exists, check that it is correct.
# LW_1min.csv already exists, check that it is correct.
# FN_1min.csv already exists, check that it is correct.
# Could not get data for TCEHY
# <Response [200]>
# Data for PFGC saved in 2022-2024 1min data\PFGC_2022-2024_1min.csv
# RUN_1min.csv already exists, check that it is correct.
# Data for NWSA saved in 2022-2024 1min data\NWSA_2022-2024_1min.csv
# Data for JHX saved in 2022-2024 1min data\JHX_2022-2024_1min.csv
# Data for J saved in 2022-2024 1min data\J_2022-2024_1min.csv
# CHX_1min.csv already exists, check that it is correct.
# QRVO_1min.csv already exists, check that it is correct.
# Waiting 1 minute before next batch...
# TTE_1min.csv already exists, check that it is correct.
# Data for EXP saved in 2022-2024 1min data\EXP_2022-2024_1min.csv
# HAS_1min.csv already exists, check that it is correct.
# BOOT_1min.csv already exists, check that it is correct.
# Data for RS saved in 2022-2024 1min data\RS_2022-2024_1min.csv
# CNK_1min.csv already exists, check that it is correct.
# HST_1min.csv already exists, check that it is correct.
# GEN_1min.csv already exists, check that it is correct.
# DBX_1min.csv already exists, check that it is correct.
# S_1min.csv already exists, check that it is correct.
# Data for EQX saved in 2022-2024 1min data\EQX_2022-2024_1min.csv
# CRS_1min.csv already exists, check that it is correct.
# Waiting 1 minute before next batch...
# BBAI_1min.csv already exists, check that it is correct.
# Could not get data for TTAN
# <Response [200]>
# Data for LAD saved in 2022-2024 1min data\LAD_2022-2024_1min.csv
# BMRN_1min.csv already exists, check that it is correct.
# FBIN_1min.csv already exists, check that it is correct.
# BERY_1min.csv already exists, check that it is correct.
# PARA_1min.csv already exists, check that it is correct.
# Data for NDSN saved in 2022-2024 1min data\NDSN_2022-2024_1min.csv
# Data for FSS saved in 2022-2024 1min data\FSS_2022-2024_1min.csv
# Data for NYT saved in 2022-2024 1min data\NYT_2022-2024_1min.csv
# TRMB_1min.csv already exists, check that it is correct.
# Could not get data for CHRO
# <Response [200]>
# Waiting 1 minute before next batch...
# YMM_1min.csv already exists, check that it is correct.
# GRAB_1min.csv already exists, check that it is correct.
# AN_1min.csv already exists, check that it is correct.
# Data for WWD saved in 2022-2024 1min data\WWD_2022-2024_1min.csv
# FSM_1min.csv already exists, check that it is correct.
# Data for CHRD saved in 2022-2024 1min data\CHRD_2022-2024_1min.csv
# Data for ERIE saved in 2022-2024 1min data\ERIE_2022-2024_1min.csv
# BEN_1min.csv already exists, check that it is correct.
# Data for KEX saved in 2022-2024 1min data\KEX_2022-2024_1min.csv
# CLH_1min.csv already exists, check that it is correct.
# MDGL_1min.csv already exists, check that it is correct.
# Data for BIP saved in 2022-2024 1min data\BIP_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# BNTX_1min.csv already exists, check that it is correct.
# PVH_1min.csv already exists, check that it is correct.
# FYBR_1min.csv already exists, check that it is correct.
# LRN_1min.csv already exists, check that it is correct.
# MAT_1min.csv already exists, check that it is correct.
# Data for KTOS saved in 2022-2024 1min data\KTOS_2022-2024_1min.csv
# QGEN_1min.csv already exists, check that it is correct.
# Data for CNX saved in 2022-2024 1min data\CNX_2022-2024_1min.csv
# ONTO_1min.csv already exists, check that it is correct.
# Could not get data for AS
# <Response [200]>
# RXRX_1min.csv already exists, check that it is correct.
# Data for GPI saved in 2022-2024 1min data\GPI_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# Data for SMG saved in 2022-2024 1min data\SMG_2022-2024_1min.csv
# DINO_1min.csv already exists, check that it is correct.
# Data for GPK saved in 2022-2024 1min data\GPK_2022-2024_1min.csv
# Data for HRI saved in 2022-2024 1min data\HRI_2022-2024_1min.csv
# FLS_1min.csv already exists, check that it is correct.
# Data for MASI saved in 2022-2024 1min data\MASI_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# MUR_1min.csv already exists, check that it is correct.
# MMYT_1min.csv already exists, check that it is correct.
# Data for RTC saved in 2022-2024 1min data\RTC_2022-2024_1min.csv
# Data for GDS saved in 2022-2024 1min data\GDS_2022-2024_1min.csv
# WSC_1min.csv already exists, check that it is correct.
# Data for EXLS saved in 2022-2024 1min data\EXLS_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# ESTC_1min.csv already exists, check that it is correct.
# Data for LKQ saved in 2022-2024 1min data\LKQ_2022-2024_1min.csv
# JKHY_1min.csv already exists, check that it is correct.
# MUSA_1min.csv already exists, check that it is correct.
# Data for FNB saved in 2022-2024 1min data\FNB_2022-2024_1min.csv
# Could not get data for ATAT
# <Response [200]>
# RGA_1min.csv already exists, check that it is correct.
# WY_1min.csv already exists, check that it is correct.
# Data for RYAN saved in 2022-2024 1min data\RYAN_2022-2024_1min.csv
# Data for GL saved in 2022-2024 1min data\GL_2022-2024_1min.csv
# INCY_1min.csv already exists, check that it is correct.
# Data for JOBY saved in 2022-2024 1min data\JOBY_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# Data for DY saved in 2022-2024 1min data\DY_2022-2024_1min.csv
# SCI_1min.csv already exists, check that it is correct.
# SLG_1min.csv already exists, check that it is correct.
# Data for SIG saved in 2022-2024 1min data\SIG_2022-2024_1min.csv
# Could not get data for BIRK
# <Response [200]>
# Could not get data for VIK
# <Response [200]>
# Waiting 1 minute before next batch...
# Data for DOX saved in 2022-2024 1min data\DOX_2022-2024_1min.csv
# Data for WTFC saved in 2022-2024 1min data\WTFC_2022-2024_1min.csv
# Could not get data for LKNCY
# <Response [200]>
# Data for MGA saved in 2022-2024 1min data\MGA_2022-2024_1min.csv
# FOUR_1min.csv already exists, check that it is correct.
# BLD_1min.csv already exists, check that it is correct.
# Waiting 1 minute before next batch...
# LAMR_1min.csv already exists, check that it is correct.
# DNN_1min.csv already exists, check that it is correct.
# Data for LMB saved in 2022-2024 1min data\LMB_2022-2024_1min.csv
# Data for WEX saved in 2022-2024 1min data\WEX_2022-2024_1min.csv
# GNRC_1min.csv already exists, check that it is correct.
# WAL_1min.csv already exists, check that it is correct.
# CPT_1min.csv already exists, check that it is correct.
# LI_1min.csv already exists, check that it is correct.
# Data for LBRT saved in 2022-2024 1min data\LBRT_2022-2024_1min.csv
# NTNX_1min.csv already exists, check that it is correct.
# Could not get data for CORZ
# <Response [200]>
# Data for AM saved in 2022-2024 1min data\AM_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# Could not get data for SNDK
# <Response [200]>
# CHE_1min.csv already exists, check that it is correct.
# KSS_1min.csv already exists, check that it is correct.
# Data for PRIM saved in 2022-2024 1min data\PRIM_2022-2024_1min.csv
# Could not get data for BTE
# <Response [200]>
# DB_1min.csv already exists, check that it is correct.
# ADMA_1min.csv already exists, check that it is correct.
# Data for KD saved in 2022-2024 1min data\KD_2022-2024_1min.csv
# INFA_1min.csv already exists, check that it is correct.
# STNE_1min.csv already exists, check that it is correct.
# Data for CHDN saved in 2022-2024 1min data\CHDN_2022-2024_1min.csv
# Data for PBF saved in 2022-2024 1min data\PBF_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# BCE_1min.csv already exists, check that it is correct.
# Data for WFRD saved in 2022-2024 1min data\WFRD_2022-2024_1min.csv
# Data for BRBR saved in 2022-2024 1min data\BRBR_2022-2024_1min.csv
# Data for IDCC saved in 2022-2024 1min data\IDCC_2022-2024_1min.csv
# BNS_1min.csv already exists, check that it is correct.
# LNW_1min.csv already exists, check that it is correct.
# Waiting 1 minute before next batch...
# TRNO_1min.csv already exists, check that it is correct.
# EPAM_1min.csv already exists, check that it is correct.
# TFX_1min.csv already exists, check that it is correct.
# Data for M saved in 2022-2024 1min data\M_2022-2024_1min.csv
# Data for CINF saved in 2022-2024 1min data\CINF_2022-2024_1min.csv
# Data for YETI saved in 2022-2024 1min data\YETI_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# Could not get data for BF.B
# <Response [200]>
# FRPT_1min.csv already exists, check that it is correct.
# ERJ_1min.csv already exists, check that it is correct.
# Data for SIRI saved in 2022-2024 1min data\SIRI_2022-2024_1min.csv
# Could not get data for SOLV
# <Response [200]>
# Could not get data for SMR
# <Response [200]>
# Data for PCOR saved in 2022-2024 1min data\PCOR_2022-2024_1min.csv
# IVZ_1min.csv already exists, check that it is correct.
# Data for ASO saved in 2022-2024 1min data\ASO_2022-2024_1min.csv
# Data for GKOS saved in 2022-2024 1min data\GKOS_2022-2024_1min.csv
# Data for MOD saved in 2022-2024 1min data\MOD_2022-2024_1min.csv
# DAR_1min.csv already exists, check that it is correct.
# Waiting 1 minute before next batch...
# COOP_1min.csv already exists, check that it is correct.
# Could not get data for DXF
# <Response [200]>
# Could not get data for DXF
# <Response [200]>
# Could not get data for DXF
# <Response [200]>
# Data for DXF saved in 2022-2024 1min data\DXF_2022-2024_1min.csv
# BAM_1min.csv already exists, check that it is correct.
# LEGN_1min.csv already exists, check that it is correct.
# Data for WGS saved in 2022-2024 1min data\WGS_2022-2024_1min.csv
# Data for FLR saved in 2022-2024 1min data\FLR_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# JNPR_1min.csv already exists, check that it is correct.
# CX_1min.csv already exists, check that it is correct.
# OPCH_1min.csv already exists, check that it is correct.
# AEG_1min.csv already exists, check that it is correct.
# Data for CBSH saved in 2022-2024 1min data\CBSH_2022-2024_1min.csv
# Data for TCBI saved in 2022-2024 1min data\TCBI_2022-2024_1min.csv
# MUFG_1min.csv already exists, check that it is correct.
# TM_1min.csv already exists, check that it is correct.
# Data for LSTR saved in 2022-2024 1min data\LSTR_2022-2024_1min.csv
# Data for CIVI saved in 2022-2024 1min data\CIVI_2022-2024_1min.csv
# Data for LFUS saved in 2022-2024 1min data\LFUS_2022-2024_1min.csv
# Data for UGI saved in 2022-2024 1min data\UGI_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# Data for GFL saved in 2022-2024 1min data\GFL_2022-2024_1min.csv
# Data for JEF saved in 2022-2024 1min data\JEF_2022-2024_1min.csv
# Could not get data for USAR
# <Response [200]>
# Data for TGI saved in 2022-2024 1min data\TGI_2022-2024_1min.csv
# Data for MMSI saved in 2022-2024 1min data\MMSI_2022-2024_1min.csv
# Data for TMHC saved in 2022-2024 1min data\TMHC_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# LITE_1min.csv already exists, check that it is correct.
# GEO_1min.csv already exists, check that it is correct.
# IBP_1min.csv already exists, check that it is correct.
# Data for CW saved in 2022-2024 1min data\CW_2022-2024_1min.csv
# RPM_1min.csv already exists, check that it is correct.
# Data for AVAV saved in 2022-2024 1min data\AVAV_2022-2024_1min.csv
# Data for ATR saved in 2022-2024 1min data\ATR_2022-2024_1min.csv
# ALSN_1min.csv already exists, check that it is correct.
# VLY_1min.csv already exists, check that it is correct.
# Data for TAL saved in 2022-2024 1min data\TAL_2022-2024_1min.csv
# Data for WLK saved in 2022-2024 1min data\WLK_2022-2024_1min.csv
# BBD_1min.csv already exists, check that it is correct.
# Waiting 1 minute before next batch...
# Data for DNOW saved in 2022-2024 1min data\DNOW_2022-2024_1min.csv
# Data for COMP saved in 2022-2024 1min data\COMP_2022-2024_1min.csv
# Data for INGR saved in 2022-2024 1min data\INGR_2022-2024_1min.csv
# Data for COLM saved in 2022-2024 1min data\COLM_2022-2024_1min.csv
# Data for TPG saved in 2022-2024 1min data\TPG_2022-2024_1min.csv
# Data for AFG saved in 2022-2024 1min data\AFG_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# Data for NEOG saved in 2022-2024 1min data\NEOG_2022-2024_1min.csv
# BIO_1min.csv already exists, check that it is correct.
# Data for SWTX saved in 2022-2024 1min data\SWTX_2022-2024_1min.csv
# Data for AMH saved in 2022-2024 1min data\AMH_2022-2024_1min.csv
# CFLT_1min.csv already exists, check that it is correct.
# CVLT_1min.csv already exists, check that it is correct.
# Waiting 1 minute before next batch...
# Data for POST saved in 2022-2024 1min data\POST_2022-2024_1min.csv
# Data for MFC saved in 2022-2024 1min data\MFC_2022-2024_1min.csv
# Data for MTH saved in 2022-2024 1min data\MTH_2022-2024_1min.csv
# Data for FL saved in 2022-2024 1min data\FL_2022-2024_1min.csv
# Could not get data for FATN
# <Response [200]>
# Could not get data for ULS
# <Response [200]>
# Waiting 1 minute before next batch...
# Data for WSBC saved in 2022-2024 1min data\WSBC_2022-2024_1min.csv
# BZ_1min.csv already exists, check that it is correct.
# BPMC_1min.csv already exists, check that it is correct.
# Data for WBS saved in 2022-2024 1min data\WBS_2022-2024_1min.csv
# AXTA_1min.csv already exists, check that it is correct.
# Data for SSB saved in 2022-2024 1min data\SSB_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# EGP_1min.csv already exists, check that it is correct.
# Data for SLM saved in 2022-2024 1min data\SLM_2022-2024_1min.csv
# Could not get data for TGL
# <Response [200]>
# Data for MORN saved in 2022-2024 1min data\MORN_2022-2024_1min.csv
# Data for LEVI saved in 2022-2024 1min data\LEVI_2022-2024_1min.csv
# PCVX_1min.csv already exists, check that it is correct.
# Waiting 1 minute before next batch...
# Data for BPOP saved in 2022-2024 1min data\BPOP_2022-2024_1min.csv
# Data for ITRI saved in 2022-2024 1min data\ITRI_2022-2024_1min.csv
# ARW_1min.csv already exists, check that it is correct.
# PII_1min.csv already exists, check that it is correct.
# PNFP_1min.csv already exists, check that it is correct.
# Data for OLED saved in 2022-2024 1min data\OLED_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# Data for ALIT saved in 2022-2024 1min data\ALIT_2022-2024_1min.csv
# Data for AMX saved in 2022-2024 1min data\AMX_2022-2024_1min.csv
# Data for NVMI saved in 2022-2024 1min data\NVMI_2022-2024_1min.csv
# Data for ENSG saved in 2022-2024 1min data\ENSG_2022-2024_1min.csv
# Data for BB saved in 2022-2024 1min data\BB_2022-2024_1min.csv
# Data for HOG saved in 2022-2024 1min data\HOG_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# GGG_1min.csv already exists, check that it is correct.
# Data for LBRDK saved in 2022-2024 1min data\LBRDK_2022-2024_1min.csv
# Data for BC saved in 2022-2024 1min data\BC_2022-2024_1min.csv
# Could not get data for ACLX
# <Response [200]>
# Data for WOLF saved in 2022-2024 1min data\WOLF_2022-2024_1min.csv
# Data for NOG saved in 2022-2024 1min data\NOG_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# SUI_1min.csv already exists, check that it is correct.
# Data for RHP saved in 2022-2024 1min data\RHP_2022-2024_1min.csv
# Data for AAP saved in 2022-2024 1min data\AAP_2022-2024_1min.csv
# SAND_1min.csv already exists, check that it is correct.
# Data for KRYS saved in 2022-2024 1min data\KRYS_2022-2024_1min.csv
# Data for BRX saved in 2022-2024 1min data\BRX_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# Data for PENN saved in 2022-2024 1min data\PENN_2022-2024_1min.csv
# NWG_1min.csv already exists, check that it is correct.
# Data for THG saved in 2022-2024 1min data\THG_2022-2024_1min.csv
# STWD_1min.csv already exists, check that it is correct.
# Data for GFS saved in 2022-2024 1min data\GFS_2022-2024_1min.csv
# AXSM_1min.csv already exists, check that it is correct.
# Waiting 1 minute before next batch...
# Data for HWC saved in 2022-2024 1min data\HWC_2022-2024_1min.csv
# FRT_1min.csv already exists, check that it is correct.
# Data for LCII saved in 2022-2024 1min data\LCII_2022-2024_1min.csv
# Data for SMTC saved in 2022-2024 1min data\SMTC_2022-2024_1min.csv
# Data for TFIN saved in 2022-2024 1min data\TFIN_2022-2024_1min.csv
# Data for NICE saved in 2022-2024 1min data\NICE_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# Data for HR saved in 2022-2024 1min data\HR_2022-2024_1min.csv
# Could not get data for KVYO
# <Response [200]>
# Could not get data for TXNM
# <Response [200]>
# TME_1min.csv already exists, check that it is correct.
# Data for PAA saved in 2022-2024 1min data\PAA_2022-2024_1min.csv
# Data for CRI saved in 2022-2024 1min data\CRI_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# Data for WH saved in 2022-2024 1min data\WH_2022-2024_1min.csv
# BTU_1min.csv already exists, check that it is correct.
# Data for RITM saved in 2022-2024 1min data\RITM_2022-2024_1min.csv
# Could not get data for NRDBY
# <Response [200]>
# Data for SLAB saved in 2022-2024 1min data\SLAB_2022-2024_1min.csv
# QFIN_1min.csv already exists, check that it is correct.
# Waiting 1 minute before next batch...
# Data for QLYS saved in 2022-2024 1min data\QLYS_2022-2024_1min.csv
# Could not get data for SOC
# <Response [200]>
# Could not get data for NXT
# <Response [200]>
# PTCT_1min.csv already exists, check that it is correct.
# Data for ATKR saved in 2022-2024 1min data\ATKR_2022-2024_1min.csv
# Data for GNTX saved in 2022-2024 1min data\GNTX_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# Data for PK saved in 2022-2024 1min data\PK_2022-2024_1min.csv
# Data for ROAD saved in 2022-2024 1min data\ROAD_2022-2024_1min.csv
# Data for TXG saved in 2022-2024 1min data\TXG_2022-2024_1min.csv
# Data for KRC saved in 2022-2024 1min data\KRC_2022-2024_1min.csv
# Data for OSIS saved in 2022-2024 1min data\OSIS_2022-2024_1min.csv
# Data for ESI saved in 2022-2024 1min data\ESI_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# Data for NUVL saved in 2022-2024 1min data\NUVL_2022-2024_1min.csv
# Data for GO saved in 2022-2024 1min data\GO_2022-2024_1min.csv
# Data for RDN saved in 2022-2024 1min data\RDN_2022-2024_1min.csv
# Data for NCNO saved in 2022-2024 1min data\NCNO_2022-2024_1min.csv
# SITE_1min.csv already exists, check that it is correct.
# THO_1min.csv already exists, check that it is correct.
# Waiting 1 minute before next batch...
# PCTY_1min.csv already exists, check that it is correct.
# WPC_1min.csv already exists, check that it is correct.
# Data for CCCS saved in 2022-2024 1min data\CCCS_2022-2024_1min.csv
# Data for MPW saved in 2022-2024 1min data\MPW_2022-2024_1min.csv
# Data for BBIO saved in 2022-2024 1min data\BBIO_2022-2024_1min.csv
# Data for LTH saved in 2022-2024 1min data\LTH_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# Data for HUT saved in 2022-2024 1min data\HUT_2022-2024_1min.csv
# Data for LEA saved in 2022-2024 1min data\LEA_2022-2024_1min.csv
# Data for NFG saved in 2022-2024 1min data\NFG_2022-2024_1min.csv
# Could not get data for FLG
# <Response [200]>
# CFR_1min.csv already exists, check that it is correct.
# PPC_1min.csv already exists, check that it is correct.
# Waiting 1 minute before next batch...
# Data for SM saved in 2022-2024 1min data\SM_2022-2024_1min.csv
# Data for NE saved in 2022-2024 1min data\NE_2022-2024_1min.csv
# Data for CADE saved in 2022-2024 1min data\CADE_2022-2024_1min.csv
# Data for ESNT saved in 2022-2024 1min data\ESNT_2022-2024_1min.csv
# Data for GBX saved in 2022-2024 1min data\GBX_2022-2024_1min.csv
# LNC_1min.csv already exists, check that it is correct.
# Waiting 1 minute before next batch...
# Data for WNC saved in 2022-2024 1min data\WNC_2022-2024_1min.csv
# Data for KRG saved in 2022-2024 1min data\KRG_2022-2024_1min.csv
# Could not get data for LVMUY
# <Response [200]>
# Data for FCN saved in 2022-2024 1min data\FCN_2022-2024_1min.csv
# Data for BHC saved in 2022-2024 1min data\BHC_2022-2024_1min.csv
# Could not get data for ABBNY
# <Response [200]>
# Waiting 1 minute before next batch...
# Data for RVMD saved in 2022-2024 1min data\RVMD_2022-2024_1min.csv
# YPF_1min.csv already exists, check that it is correct.
# Data for BILI saved in 2022-2024 1min data\BILI_2022-2024_1min.csv
# Data for ARCO saved in 2022-2024 1min data\ARCO_2022-2024_1min.csv
# Data for MGY saved in 2022-2024 1min data\MGY_2022-2024_1min.csv
# Data for SEIC saved in 2022-2024 1min data\SEIC_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# Data for WU saved in 2022-2024 1min data\WU_2022-2024_1min.csv
# Data for WRBY saved in 2022-2024 1min data\WRBY_2022-2024_1min.csv
# Data for TNET saved in 2022-2024 1min data\TNET_2022-2024_1min.csv
# Data for ATGE saved in 2022-2024 1min data\ATGE_2022-2024_1min.csv
# Data for PI saved in 2022-2024 1min data\PI_2022-2024_1min.csv
# Data for PRCT saved in 2022-2024 1min data\PRCT_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# Data for RELY saved in 2022-2024 1min data\RELY_2022-2024_1min.csv
# WEN_1min.csv already exists, check that it is correct.
# Data for ALKS saved in 2022-2024 1min data\ALKS_2022-2024_1min.csv
# Data for PEGA saved in 2022-2024 1min data\PEGA_2022-2024_1min.csv
# AI_1min.csv already exists, check that it is correct.
# Data for L saved in 2022-2024 1min data\L_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# Data for FULT saved in 2022-2024 1min data\FULT_2022-2024_1min.csv
# Data for GNW saved in 2022-2024 1min data\GNW_2022-2024_1min.csv
# Data for ELAN saved in 2022-2024 1min data\ELAN_2022-2024_1min.csv
# REG_1min.csv already exists, check that it is correct.
# Data for TS saved in 2022-2024 1min data\TS_2022-2024_1min.csv
# HBM_1min.csv already exists, check that it is correct.
# Waiting 1 minute before next batch...
# Could not get data for LOAR
# <Response [200]>
# Data for MT saved in 2022-2024 1min data\MT_2022-2024_1min.csv
# Data for VIRT saved in 2022-2024 1min data\VIRT_2022-2024_1min.csv
# Data for OMF saved in 2022-2024 1min data\OMF_2022-2024_1min.csv
# Data for TTC saved in 2022-2024 1min data\TTC_2022-2024_1min.csv
# Data for RYAAY saved in 2022-2024 1min data\RYAAY_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# Data for SMFG saved in 2022-2024 1min data\SMFG_2022-2024_1min.csv
# Could not get data for CNR
# <Response [200]>
# Data for GLPI saved in 2022-2024 1min data\GLPI_2022-2024_1min.csv
# Data for MRCY saved in 2022-2024 1min data\MRCY_2022-2024_1min.csv
# Data for EEFT saved in 2022-2024 1min data\EEFT_2022-2024_1min.csv
# Data for APLS saved in 2022-2024 1min data\APLS_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# Data for SPXC saved in 2022-2024 1min data\SPXC_2022-2024_1min.csv
# Data for AVT saved in 2022-2024 1min data\AVT_2022-2024_1min.csv
# Data for TIGO saved in 2022-2024 1min data\TIGO_2022-2024_1min.csv
# Data for NSP saved in 2022-2024 1min data\NSP_2022-2024_1min.csv
# Could not get data for CRUS
# <Response [503]>
# Data for CRUS saved in 2022-2024 1min data\CRUS_2022-2024_1min.csv
# Data for WHD saved in 2022-2024 1min data\WHD_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# Data for SAIC saved in 2022-2024 1min data\SAIC_2022-2024_1min.csv
# Data for KC saved in 2022-2024 1min data\KC_2022-2024_1min.csv
# Data for HOMB saved in 2022-2024 1min data\HOMB_2022-2024_1min.csv
# Data for EPRT saved in 2022-2024 1min data\EPRT_2022-2024_1min.csv
# Could not get data for WAY
# <Response [200]>
# Data for VRNA saved in 2022-2024 1min data\VRNA_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# LNTH_1min.csv already exists, check that it is correct.
# Data for KAI saved in 2022-2024 1min data\KAI_2022-2024_1min.csv
# Data for COKE saved in 2022-2024 1min data\COKE_2022-2024_1min.csv
# Data for VAL saved in 2022-2024 1min data\VAL_2022-2024_1min.csv
# BILL_1min.csv already exists, check that it is correct.
# Data for BOH saved in 2022-2024 1min data\BOH_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# Data for FMC saved in 2022-2024 1min data\FMC_2022-2024_1min.csv
# Data for HESM saved in 2022-2024 1min data\HESM_2022-2024_1min.csv
# Data for G saved in 2022-2024 1min data\G_2022-2024_1min.csv
# Data for MHK saved in 2022-2024 1min data\MHK_2022-2024_1min.csv
# Data for KNSL saved in 2022-2024 1min data\KNSL_2022-2024_1min.csv
# Data for BYD saved in 2022-2024 1min data\BYD_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# Data for BHVN saved in 2022-2024 1min data\BHVN_2022-2024_1min.csv
# Could not get data for AACT
# <Response [200]>
# GLOB_1min.csv already exists, check that it is correct.
# Data for JWN saved in 2022-2024 1min data\JWN_2022-2024_1min.csv
# CYTK_1min.csv already exists, check that it is correct.
# Data for IMO saved in 2022-2024 1min data\IMO_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# Data for ROOT saved in 2022-2024 1min data\ROOT_2022-2024_1min.csv
# ZIM_1min.csv already exists, check that it is correct.
# Data for MSM saved in 2022-2024 1min data\MSM_2022-2024_1min.csv
# Data for HCC saved in 2022-2024 1min data\HCC_2022-2024_1min.csv
# Data for CBRL saved in 2022-2024 1min data\CBRL_2022-2024_1min.csv
# AAON_1min.csv already exists, check that it is correct.
# Waiting 1 minute before next batch...
# Could not get data for DRS
# <Response [200]>
# Data for LECO saved in 2022-2024 1min data\LECO_2022-2024_1min.csv
# Data for LKFN saved in 2022-2024 1min data\LKFN_2022-2024_1min.csv
# Data for CAKE saved in 2022-2024 1min data\CAKE_2022-2024_1min.csv
# APG_1min.csv already exists, check that it is correct.
# COTY_1min.csv already exists, check that it is correct.
# Waiting 1 minute before next batch...
# Could not get data for NMAX
# <Response [200]>
# Data for ING saved in 2022-2024 1min data\ING_2022-2024_1min.csv
# Data for NXST saved in 2022-2024 1min data\NXST_2022-2024_1min.csv
# TGTX_1min.csv already exists, check that it is correct.
# IREN_1min.csv already exists, check that it is correct.
# Data for BMO saved in 2022-2024 1min data\BMO_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# Data for SBRA saved in 2022-2024 1min data\SBRA_2022-2024_1min.csv
# Data for VSCO saved in 2022-2024 1min data\VSCO_2022-2024_1min.csv
# Data for RNA saved in 2022-2024 1min data\RNA_2022-2024_1min.csv
# Data for GMED saved in 2022-2024 1min data\GMED_2022-2024_1min.csv
# Data for CWH saved in 2022-2024 1min data\CWH_2022-2024_1min.csv
# Data for DAN saved in 2022-2024 1min data\DAN_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# Data for DEI saved in 2022-2024 1min data\DEI_2022-2024_1min.csv
# Data for MTG saved in 2022-2024 1min data\MTG_2022-2024_1min.csv
# Data for UMBF saved in 2022-2024 1min data\UMBF_2022-2024_1min.csv
# Data for FTDR saved in 2022-2024 1min data\FTDR_2022-2024_1min.csv
# Data for FUBO saved in 2022-2024 1min data\FUBO_2022-2024_1min.csv
# Could not get data for OBDC
# <Response [200]>
# Waiting 1 minute before next batch...
# Data for POR saved in 2022-2024 1min data\POR_2022-2024_1min.csv
# Data for HEES saved in 2022-2024 1min data\HEES_2022-2024_1min.csv
# Data for DX saved in 2022-2024 1min data\DX_2022-2024_1min.csv
# Data for TKR saved in 2022-2024 1min data\TKR_2022-2024_1min.csv
# Data for OGE saved in 2022-2024 1min data\OGE_2022-2024_1min.csv
# JXN_1min.csv already exists, check that it is correct.
# Waiting 1 minute before next batch...
# NOV_1min.csv already exists, check that it is correct.
# Data for FORM saved in 2022-2024 1min data\FORM_2022-2024_1min.csv
# Data for TU saved in 2022-2024 1min data\TU_2022-2024_1min.csv
# Data for NNN saved in 2022-2024 1min data\NNN_2022-2024_1min.csv
# Data for AMR saved in 2022-2024 1min data\AMR_2022-2024_1min.csv
# Data for VIPS saved in 2022-2024 1min data\VIPS_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# Data for WMS saved in 2022-2024 1min data\WMS_2022-2024_1min.csv
# Data for WTS saved in 2022-2024 1min data\WTS_2022-2024_1min.csv
# Data for VNET saved in 2022-2024 1min data\VNET_2022-2024_1min.csv
# Data for FMX saved in 2022-2024 1min data\FMX_2022-2024_1min.csv
# WTRG_1min.csv already exists, check that it is correct.
# Data for CUZ saved in 2022-2024 1min data\CUZ_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# TMC_1min.csv already exists, check that it is correct.
# Data for GLNG saved in 2022-2024 1min data\GLNG_2022-2024_1min.csv
# Could not get data for BAESY
# <Response [200]>
# Data for RYTM saved in 2022-2024 1min data\RYTM_2022-2024_1min.csv
# Data for MATX saved in 2022-2024 1min data\MATX_2022-2024_1min.csv
# CRSP_1min.csv already exists, check that it is correct.
# Waiting 1 minute before next batch...
# Data for GFF saved in 2022-2024 1min data\GFF_2022-2024_1min.csv
# Data for FCF saved in 2022-2024 1min data\FCF_2022-2024_1min.csv
# Data for TFII saved in 2022-2024 1min data\TFII_2022-2024_1min.csv
# Data for HMC saved in 2022-2024 1min data\HMC_2022-2024_1min.csv
# Data for EXK saved in 2022-2024 1min data\EXK_2022-2024_1min.csv
# Data for DDS saved in 2022-2024 1min data\DDS_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# Data for PBA saved in 2022-2024 1min data\PBA_2022-2024_1min.csv
# ...
# Data for CUBE saved in 2022-2024 1min data\CUBE_2022-2024_1min.csv
# Data for MC saved in 2022-2024 1min data\MC_2022-2024_1min.csv
# Data for CR saved in 2022-2024 1min data\CR_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# Data for COLD saved in 2022-2024 1min data\COLD_2022-2024_1min.csv
# Data for CMC saved in 2022-2024 1min data\CMC_2022-2024_1min.csv
# Data for LOGI saved in 2022-2024 1min data\LOGI_2022-2024_1min.csv
# Data for RELX saved in 2022-2024 1min data\RELX_2022-2024_1min.csv
# Data for GVA saved in 2022-2024 1min data\GVA_2022-2024_1min.csv
# Data for BFH saved in 2022-2024 1min data\BFH_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# Data for ARIS saved in 2022-2024 1min data\ARIS_2022-2024_1min.csv
# Data for CTRE saved in 2022-2024 1min data\CTRE_2022-2024_1min.csv
# Data for UFPI saved in 2022-2024 1min data\UFPI_2022-2024_1min.csv
# AWI_1min.csv already exists, check that it is correct.
# Data for HURN saved in 2022-2024 1min data\HURN_2022-2024_1min.csv
# Data for CRK saved in 2022-2024 1min data\CRK_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# Data for ORA saved in 2022-2024 1min data\ORA_2022-2024_1min.csv
# Data for BANC saved in 2022-2024 1min data\BANC_2022-2024_1min.csv
# Data for PLAY saved in 2022-2024 1min data\PLAY_2022-2024_1min.csv
# Could not get data for JBTM
# <Response [200]>
# Data for FUN saved in 2022-2024 1min data\FUN_2022-2024_1min.csv
# Data for XRAY saved in 2022-2024 1min data\XRAY_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# Data for BXSL saved in 2022-2024 1min data\BXSL_2022-2024_1min.csv
# Data for EGO saved in 2022-2024 1min data\EGO_2022-2024_1min.csv
# Data for BWA saved in 2022-2024 1min data\BWA_2022-2024_1min.csv
# Data for CALX saved in 2022-2024 1min data\CALX_2022-2024_1min.csv
# Data for GENI saved in 2022-2024 1min data\GENI_2022-2024_1min.csv
# Data for TDS saved in 2022-2024 1min data\TDS_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# Data for UEC saved in 2022-2024 1min data\UEC_2022-2024_1min.csv
# Data for APPF saved in 2022-2024 1min data\APPF_2022-2024_1min.csv
# Data for PAGP saved in 2022-2024 1min data\PAGP_2022-2024_1min.csv
# Data for OSK saved in 2022-2024 1min data\OSK_2022-2024_1min.csv
# Data for TBBK saved in 2022-2024 1min data\TBBK_2022-2024_1min.csv
# Data for CBZ saved in 2022-2024 1min data\CBZ_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# Data for SAM saved in 2022-2024 1min data\SAM_2022-2024_1min.csv
# Data for HUN saved in 2022-2024 1min data\HUN_2022-2024_1min.csv
# Data for ABG saved in 2022-2024 1min data\ABG_2022-2024_1min.csv
# Data for GRND saved in 2022-2024 1min data\GRND_2022-2024_1min.csv
# Data for RDNT saved in 2022-2024 1min data\RDNT_2022-2024_1min.csv
# Data for FAF saved in 2022-2024 1min data\FAF_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# Data for NWE saved in 2022-2024 1min data\NWE_2022-2024_1min.csv
# Data for SEE saved in 2022-2024 1min data\SEE_2022-2024_1min.csv
# Could not get data for SMNEY
# <Response [200]>
# EDU_1min.csv already exists, check that it is correct.
# Data for GT saved in 2022-2024 1min data\GT_2022-2024_1min.csv
# Data for VMI saved in 2022-2024 1min data\VMI_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# Data for WNS saved in 2022-2024 1min data\WNS_2022-2024_1min.csv
# Data for HGV saved in 2022-2024 1min data\HGV_2022-2024_1min.csv
# Data for STAG saved in 2022-2024 1min data\STAG_2022-2024_1min.csv
# Data for CM saved in 2022-2024 1min data\CM_2022-2024_1min.csv
# Could not get data for SEZL
# <Response [200]>
# Data for POWL saved in 2022-2024 1min data\POWL_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# Data for HLI saved in 2022-2024 1min data\HLI_2022-2024_1min.csv
# Data for APLE saved in 2022-2024 1min data\APLE_2022-2024_1min.csv
# Data for CPRI saved in 2022-2024 1min data\CPRI_2022-2024_1min.csv
# Data for ORI saved in 2022-2024 1min data\ORI_2022-2024_1min.csv
# Data for ZWS saved in 2022-2024 1min data\ZWS_2022-2024_1min.csv
# Could not get data for LZAGY
# <Response [200]>
# Waiting 1 minute before next batch...
# Data for ARR saved in 2022-2024 1min data\ARR_2022-2024_1min.csv
# Data for TPH saved in 2022-2024 1min data\TPH_2022-2024_1min.csv
# Could not get data for JNVR
# <Response [200]>
# MTSI_1min.csv already exists, check that it is correct.
# Data for LANC saved in 2022-2024 1min data\LANC_2022-2024_1min.csv
# Data for RMBS saved in 2022-2024 1min data\RMBS_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# Data for REVG saved in 2022-2024 1min data\REVG_2022-2024_1min.csv
# Data for CVCO saved in 2022-2024 1min data\CVCO_2022-2024_1min.csv
# Data for NOVT saved in 2022-2024 1min data\NOVT_2022-2024_1min.csv
# Data for WERN saved in 2022-2024 1min data\WERN_2022-2024_1min.csv
# Data for PFSI saved in 2022-2024 1min data\PFSI_2022-2024_1min.csv
# WULF_1min.csv already exists, check that it is correct.
# Waiting 1 minute before next batch...
# Data for OSCR saved in 2022-2024 1min data\OSCR_2022-2024_1min.csv
# Data for BAP saved in 2022-2024 1min data\BAP_2022-2024_1min.csv
# Data for TGB saved in 2022-2024 1min data\TGB_2022-2024_1min.csv
# Data for JHG saved in 2022-2024 1min data\JHG_2022-2024_1min.csv
# Data for LPX saved in 2022-2024 1min data\LPX_2022-2024_1min.csv
# Could not get data for SARO
# <Response [200]>
# Waiting 1 minute before next batch...
# Data for VRNS saved in 2022-2024 1min data\VRNS_2022-2024_1min.csv
# Data for SNEX saved in 2022-2024 1min data\SNEX_2022-2024_1min.csv
# Data for SMPL saved in 2022-2024 1min data\SMPL_2022-2024_1min.csv
# Data for RDY saved in 2022-2024 1min data\RDY_2022-2024_1min.csv
# Data for FCFS saved in 2022-2024 1min data\FCFS_2022-2024_1min.csv
# Data for IHG saved in 2022-2024 1min data\IHG_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# Data for OGS saved in 2022-2024 1min data\OGS_2022-2024_1min.csv
# Data for FUL saved in 2022-2024 1min data\FUL_2022-2024_1min.csv
# Data for OGN saved in 2022-2024 1min data\OGN_2022-2024_1min.csv
# Data for GIB saved in 2022-2024 1min data\GIB_2022-2024_1min.csv
# Data for SAN saved in 2022-2024 1min data\SAN_2022-2024_1min.csv
# Data for IDA saved in 2022-2024 1min data\IDA_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# Data for ACVA saved in 2022-2024 1min data\ACVA_2022-2024_1min.csv
# Data for MAIN saved in 2022-2024 1min data\MAIN_2022-2024_1min.csv
# Data for FTS saved in 2022-2024 1min data\FTS_2022-2024_1min.csv
# AUB_1min.csv already exists, check that it is correct.
# Data for KNTK saved in 2022-2024 1min data\KNTK_2022-2024_1min.csv
# Data for ABR saved in 2022-2024 1min data\ABR_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# Data for TPC saved in 2022-2024 1min data\TPC_2022-2024_1min.csv
# Data for NVST saved in 2022-2024 1min data\NVST_2022-2024_1min.csv
# Data for SLGN saved in 2022-2024 1min data\SLGN_2022-2024_1min.csv
# Could not get data for MBLY
# <Response [200]>
# Data for TDW saved in 2022-2024 1min data\TDW_2022-2024_1min.csv
# Data for PRLB saved in 2022-2024 1min data\PRLB_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# Data for HAE saved in 2022-2024 1min data\HAE_2022-2024_1min.csv
# Data for LOPE saved in 2022-2024 1min data\LOPE_2022-2024_1min.csv
# Data for TTEK saved in 2022-2024 1min data\TTEK_2022-2024_1min.csv
# Data for GXO saved in 2022-2024 1min data\GXO_2022-2024_1min.csv
# Data for TSEM saved in 2022-2024 1min data\TSEM_2022-2024_1min.csv
# Data for PCH saved in 2022-2024 1min data\PCH_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# Data for NXE saved in 2022-2024 1min data\NXE_2022-2024_1min.csv
# Data for SPSC saved in 2022-2024 1min data\SPSC_2022-2024_1min.csv
# Data for NWL saved in 2022-2024 1min data\NWL_2022-2024_1min.csv
# Data for AL saved in 2022-2024 1min data\AL_2022-2024_1min.csv
# Could not get data for MCHPP
# <Response [200]>
# Data for UTZ saved in 2022-2024 1min data\UTZ_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# Data for ZI saved in 2022-2024 1min data\ZI_2022-2024_1min.csv
# Could not get data for VG
# <Response [200]>
# Data for DCI saved in 2022-2024 1min data\DCI_2022-2024_1min.csv
# Data for ARMK saved in 2022-2024 1min data\ARMK_2022-2024_1min.csv
# Data for PB saved in 2022-2024 1min data\PB_2022-2024_1min.csv
# Data for PJT saved in 2022-2024 1min data\PJT_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# Data for CRGY saved in 2022-2024 1min data\CRGY_2022-2024_1min.csv
# Data for DORM saved in 2022-2024 1min data\DORM_2022-2024_1min.csv
# Data for VVV saved in 2022-2024 1min data\VVV_2022-2024_1min.csv
# Data for ST saved in 2022-2024 1min data\ST_2022-2024_1min.csv
# Data for PAG saved in 2022-2024 1min data\PAG_2022-2024_1min.csv
# Data for DVAX saved in 2022-2024 1min data\DVAX_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# Data for FRO saved in 2022-2024 1min data\FRO_2022-2024_1min.csv
# Data for NFE saved in 2022-2024 1min data\NFE_2022-2024_1min.csv
# Data for KT saved in 2022-2024 1min data\KT_2022-2024_1min.csv
# Could not get data for KNF
# <Response [200]>
# Data for RLI saved in 2022-2024 1min data\RLI_2022-2024_1min.csv
# Data for MHO saved in 2022-2024 1min data\MHO_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# Data for LUNR saved in 2022-2024 1min data\LUNR_2022-2024_1min.csv
# Data for INOD saved in 2022-2024 1min data\INOD_2022-2024_1min.csv
# Data for GHC saved in 2022-2024 1min data\GHC_2022-2024_1min.csv
# Data for VNO saved in 2022-2024 1min data\VNO_2022-2024_1min.csv
# Data for BLBD saved in 2022-2024 1min data\BLBD_2022-2024_1min.csv
# Data for CERT saved in 2022-2024 1min data\CERT_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# Data for PGRE saved in 2022-2024 1min data\PGRE_2022-2024_1min.csv
# Data for BKH saved in 2022-2024 1min data\BKH_2022-2024_1min.csv
# Data for AMG saved in 2022-2024 1min data\AMG_2022-2024_1min.csv
# Data for BFAM saved in 2022-2024 1min data\BFAM_2022-2024_1min.csv
# Data for UI saved in 2022-2024 1min data\UI_2022-2024_1min.csv
# Data for LEU saved in 2022-2024 1min data\LEU_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# ACT_1min.csv already exists, check that it is correct.
# Data for PUK saved in 2022-2024 1min data\PUK_2022-2024_1min.csv
# Could not get data for DIDIY
# <Response [200]>
# Data for FOX saved in 2022-2024 1min data\FOX_2022-2024_1min.csv
# Could not get data for AMTM
# <Response [200]>
# Data for IOVA saved in 2022-2024 1min data\IOVA_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# Data for LUMN saved in 2022-2024 1min data\LUMN_2022-2024_1min.csv
# Could not get data for AHR
# <Response [200]>
# SDGR_1min.csv already exists, check that it is correct.
# Data for CLM saved in 2022-2024 1min data\CLM_2022-2024_1min.csv
# Data for BRZE saved in 2022-2024 1min data\BRZE_2022-2024_1min.csv
# Data for NVAX saved in 2022-2024 1min data\NVAX_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# Data for SHOO saved in 2022-2024 1min data\SHOO_2022-2024_1min.csv
# Data for WES saved in 2022-2024 1min data\WES_2022-2024_1min.csv
# Data for ACA saved in 2022-2024 1min data\ACA_2022-2024_1min.csv
# Data for ATEN saved in 2022-2024 1min data\ATEN_2022-2024_1min.csv
# Data for TAK saved in 2022-2024 1min data\TAK_2022-2024_1min.csv
# Data for XENE saved in 2022-2024 1min data\XENE_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# Data for INDB saved in 2022-2024 1min data\INDB_2022-2024_1min.csv
# Data for ZD saved in 2022-2024 1min data\ZD_2022-2024_1min.csv
# Data for ABCB saved in 2022-2024 1min data\ABCB_2022-2024_1min.csv
# Data for NMIH saved in 2022-2024 1min data\NMIH_2022-2024_1min.csv
# Data for FSK saved in 2022-2024 1min data\FSK_2022-2024_1min.csv
# Data for QTWO saved in 2022-2024 1min data\QTWO_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# Could not get data for HSAI
# <Response [200]>
# Data for RPD saved in 2022-2024 1min data\RPD_2022-2024_1min.csv
# Data for ICUI saved in 2022-2024 1min data\ICUI_2022-2024_1min.csv
# Could not get data for ECG
# <Response [200]>
# Data for ENVX saved in 2022-2024 1min data\ENVX_2022-2024_1min.csv
# Data for SLF saved in 2022-2024 1min data\SLF_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# Data for OLN saved in 2022-2024 1min data\OLN_2022-2024_1min.csv
# Data for TGNA saved in 2022-2024 1min data\TGNA_2022-2024_1min.csv
# SRRK_1min.csv already exists, check that it is correct.
# Data for TNL saved in 2022-2024 1min data\TNL_2022-2024_1min.csv
# Data for SR saved in 2022-2024 1min data\SR_2022-2024_1min.csv
# Data for SKY saved in 2022-2024 1min data\SKY_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# Data for IDYA saved in 2022-2024 1min data\IDYA_2022-2024_1min.csv
# Data for SON saved in 2022-2024 1min data\SON_2022-2024_1min.csv
# Could not get data for KSPI
# <Response [200]>
# Data for KTB saved in 2022-2024 1min data\KTB_2022-2024_1min.csv
# Data for HP saved in 2022-2024 1min data\HP_2022-2024_1min.csv
# Could not get data for WKC
# <Response [200]>
# Waiting 1 minute before next batch...
# Data for AX saved in 2022-2024 1min data\AX_2022-2024_1min.csv
# Data for GATX saved in 2022-2024 1min data\GATX_2022-2024_1min.csv
# Data for BOX saved in 2022-2024 1min data\BOX_2022-2024_1min.csv
# Data for TWST saved in 2022-2024 1min data\TWST_2022-2024_1min.csv
# Data for ARVN saved in 2022-2024 1min data\ARVN_2022-2024_1min.csv
# Data for CACC saved in 2022-2024 1min data\CACC_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# Data for IAC saved in 2022-2024 1min data\IAC_2022-2024_1min.csv
# Data for BKD saved in 2022-2024 1min data\BKD_2022-2024_1min.csv
# Data for QUBT saved in 2022-2024 1min data\QUBT_2022-2024_1min.csv
# Data for VERX saved in 2022-2024 1min data\VERX_2022-2024_1min.csv
# Data for ESGR saved in 2022-2024 1min data\ESGR_2022-2024_1min.csv
# Data for AMKR saved in 2022-2024 1min data\AMKR_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# Could not get data for PROSY
# <Response [200]>
# Data for PRI saved in 2022-2024 1min data\PRI_2022-2024_1min.csv
# Data for SATS saved in 2022-2024 1min data\SATS_2022-2024_1min.csv
# Data for SANM saved in 2022-2024 1min data\SANM_2022-2024_1min.csv
# Data for RCI saved in 2022-2024 1min data\RCI_2022-2024_1min.csv
# Data for ARWR saved in 2022-2024 1min data\ARWR_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# Data for ZETA saved in 2022-2024 1min data\ZETA_2022-2024_1min.csv
# Data for AMRC saved in 2022-2024 1min data\AMRC_2022-2024_1min.csv
# Data for CNXC saved in 2022-2024 1min data\CNXC_2022-2024_1min.csv
# Data for DV saved in 2022-2024 1min data\DV_2022-2024_1min.csv
# Data for PLMR saved in 2022-2024 1min data\PLMR_2022-2024_1min.csv
# Data for EVH saved in 2022-2024 1min data\EVH_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# ROIV_1min.csv already exists, check that it is correct.
# EOSE_1min.csv already exists, check that it is correct.
# Data for PGNY saved in 2022-2024 1min data\PGNY_2022-2024_1min.csv
# Data for CBT saved in 2022-2024 1min data\CBT_2022-2024_1min.csv
# Data for ENFN saved in 2022-2024 1min data\ENFN_2022-2024_1min.csv
# Data for BEPC saved in 2022-2024 1min data\BEPC_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# Data for BHF saved in 2022-2024 1min data\BHF_2022-2024_1min.csv
# Could not get data for UCB
# <Response [200]>
# Data for AMPS saved in 2022-2024 1min data\AMPS_2022-2024_1min.csv
# Data for TDOC saved in 2022-2024 1min data\TDOC_2022-2024_1min.csv
# Data for CHH saved in 2022-2024 1min data\CHH_2022-2024_1min.csv
# Data for KBR saved in 2022-2024 1min data\KBR_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# Could not get data for NNE
# <Response [200]>
# Could not get data for HEI.A
# <Response [200]>
# Data for CWK saved in 2022-2024 1min data\CWK_2022-2024_1min.csv
# Data for KFY saved in 2022-2024 1min data\KFY_2022-2024_1min.csv
# Could not get data for ESAB
# <Response [200]>
# Data for IRTC saved in 2022-2024 1min data\IRTC_2022-2024_1min.csv
# Waiting 1 minute before next batch...
# Data for GPOR saved in 2022-2024 1min data\GPOR_2022-2024_1min.csv
# Could not get data for LINE
# <Response [200]>
# Could not get data for RNMBY
# <Response [200]>
# Data for SKYW saved in 2022-2024 1min data\SKYW_2022-2024_1min.csv
# Waiting 1 minute before next batch...
